# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya52521/Hotel_Booking_Aanalysis/blob/main/Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name :**    Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# Aditya Kumar
#
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Hotels play a crucial role in the tourism and hospitality industry. Understanding the dynamics of hotel bookings and guest behavior can significantly impact business strategies and decision-making. This Capstone project aims to conduct comprehensive exploratory data analysis (EDA) on a hotel booking dataset, leveraging data visualization and statistical techniques to uncover valuable insights.This project will focus on exploring a dataset comprising hotel-related information, including reservation details, guest demographics, and booking specifics. The dataset encompasses diverse dimensions, such as booking channels, room types, and guest characteristics, allowing for a comprehensive analysis.The project will follow a structured EDA methodology, including data preparation, visualization, statistical analysis, and interpretation of findings. Tools such as Python, pandas, matplotlib, seaborn will be used extensively.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/aditya52521/Hotel_Booking_Aanalysis/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The problem at hand is to analyze a hotel booking dataset comprehensively, with the following objectives:
#
# Booking Patterns
#
# Cancellation Analysis
#
# Room Assignment Dynamics
#
# Lead Time Impact
#
# Guest Preferences

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# #### Duplicate Values

# %%
duplicate_rows = df.duplicated()
num_duplicates = duplicate_rows.sum()
print(f"Number of duplicate rows: {num_duplicates}")
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Number of duplicate rows: 31994
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
missing_values = df.isnull()
missing_count = missing_values.sum()

# %%
sns.heatmap(missing_values, cmap="viridis", cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *Answer* Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
df[df.duplicated()].shape
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Handle the Missing Values

# %%
df[['company','agent']] = df[['company','agent']].fillna(0)

# %%
df['children'].fillna(df['children'].mean(), inplace = True)

# %%
df['country'].fillna('others', inplace = True)

# %%
df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# company               81993
# agent                 12141
# country                 447
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %%
df[df['adults']+df['babies']+df['children'] == 0].shape
# Out:
# (0, 32)

# %%
df.drop(df[df['adults']+df['babies']+df['children'] == 0].index, inplace = True)

# %%
df[['children', 'company', 'agent']] = df[['children', 'company', 'agent']].astype('int64')

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
#  Chart - 1(Bar chart of hotel types)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='hotel')
plt.title('Hotel Types')
plt.xlabel('Hotel')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart is picked to know about wgich type of hotel has highest booking type

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City Hotel has Highest bboking

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Developing city Hotels more will help in the growth of business

# %% [markdown]
# Chart - 2 (Bar chart of cancellations)

# %%
room_cancellation_rates = df.groupby('assigned_room_type')['is_canceled'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='assigned_room_type', y='is_canceled', data=room_cancellation_rates)
plt.xlabel('Assigned Room Type')
plt.ylabel('Cancellation Rate')
plt.title('Cancellation Rates by Room Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is important to Analyse which room type has a Highest Cancellation Rate

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Room Type L has Highest cancellation RAte

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the "Cancellation Rates by Room Type" bar chart can potentially have a positive business impact, as they provide valuable information for hotel management to optimize their operations and improve guest satisfaction.

# %% [markdown]
# Chart - 3  (Lead Time vs. Booking Changes)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='lead_time', y='booking_changes', data=df, alpha=0.5)
plt.xlabel('Lead Time (days)')
plt.ylabel('Booking Changes')
plt.title('Lead Time vs. Booking Changes')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# From the scatter plot, we can observe the distribution of data points. If the points are scattered randomly with no clear pattern, it suggests that there is no strong linear relationship between lead time and booking changes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Lower Value of Lead Time corresponds to lower Booking changes

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If there is a discernible pattern, hotel management can tailor their booking processes or policies to better accommodate the needs or preferences of guests with specific lead times. For example, if guests with longer lead times tend to make more changes, the hotel can offer more flexible booking options for such guests.

# %% [markdown]
# Chart - 4 (Pie chart of customer types)

# %%
customer_type_counts = df['customer_type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(customer_type_counts, labels=customer_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Customer Types')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart will helps to understand the which customer types has highest booking rate

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Transient Type of customer has highest booking rates

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Group Customers has lower value of booking rate so we can make some special offers to attract the customer with group type category

# %% [markdown]
# #### Chart - 5   (Correlation HeatMap)

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-31-4dc302938574>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation Matrix chart to visualize the correlation between numeric variables in your hotel booking dataset because it's a powerful tool for understanding relationships and dependencies between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Positive values in the heatmap indicate positive correlations between variables.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding which variables are positively correlated with average daily rate (ADR) can help the hotel set pricing strategies.

# %% [markdown]
# #####Chart - 6 (Bar Chart: Market Segment Distribution)

# %%
market_segment_distribution = df['market_segment'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=market_segment_distribution.index, y=market_segment_distribution.values)
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.title('Market Segment Distribution')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This Specific chart is Import To anlyze which Market segment has Highest Number of booking

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Online TA Market Segment shows Highest Number of booking

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Aviation Market Segment has Very Low Number of Booking so we can check with any issue with that particular segment

# %% [markdown]
# #### Chart - 7 (Pie Chart: Reservation Status Distribution)

# %%
reservation_status_distribution = df['reservation_status'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(reservation_status_distribution, labels=reservation_status_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('Reservation Status Distribution')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the Pie Chart to visualize the distribution of reservation statuses because it's an effective way to showcase the breakdown of categorical data with distinct categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Pie Chart is suitable for displaying the distribution of categorical data, such as different reservation statuses in this case.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A high percentage of "Canceled" bookings may indicate issues with booking processes or customer service. Failing to address these issues could result in decreased guest satisfaction and potential negative reviews.

# %% [markdown]
# #### Chart - 8(Histogram: Distribution of Lead Time)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['lead_time'], bins=30, kde=True)
plt.xlabel('Lead Time (days)')
plt.ylabel('Frequency')
plt.title('Distribution of Lead Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the Histogram to visualize the distribution of lead time because it is an effective chart for understanding the frequency distribution of a numeric variable, in this case, the lead time for hotel bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Histograms are excellent for gaining insights into the distribution of a single numeric variable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# the insights gained from the lead time histogram can positively impact business operations by optimizing staffing, pricing strategies, and marketing efforts. However, neglecting these insights may lead to inefficiencies and missed revenue opportunities, potentially resulting in negative growth and reduced customer satisfaction.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Implement dynamic pricing strategies that align with booking trends. Offer discounts or incentives for guests who book well in advance, and consider last-minute deals for those with shorter lead times.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this Capstone Project on Hotel Booking Analysis, we conducted a thorough exploration of a hotel booking dataset to uncover valuable insights and patterns that can inform decision-making in the hospitality industry. The project focused on several key aspects, including booking trends over time, cancellation rates, room assignment dynamics, lead time impact, and guest preferences.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
